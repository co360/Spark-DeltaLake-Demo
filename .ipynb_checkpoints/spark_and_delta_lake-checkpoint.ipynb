# %% [markdown]
# # Data Lakehouse Demo: Showcase of Apache Spark and Delta Lake

# %% [markdown]
# <img src = "https://databricks.com/wp-content/uploads/2021/10/Databricks-lakehouse-platform-2.png" width = 520>

# %%
# turn off warnings (optional)
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Ingest Raw Data Into Data Lakehouse

# %% [markdown]
# ### Gather Raw Data From Data Store

# %%
# define function to handle downloading a file from a given url
import requests 
def download_url(url, save_path, chunk_size = 128):
    r = requests.get(url, stream = True)
    with open(save_path, 'wb') as fd:
        for chunk in r.iter_content(chunk_size = chunk_size):
            fd.write(chunk)

# %%
# download zip file from website 
# normally, data would probably be stored in elastic cloud storage―e.g., AWS S3
download_url("https://github.com/JoeKnittel/joeknittel.github.io/raw/main/tidymodels_data.zip", "data.zip")

# %%
# unzip zip file
import zipfile
with zipfile.ZipFile("./data.zip", 'r') as zip_ref:
    zip_ref.extractall("./")

# %% [markdown]
# ### Create a SparkSession with Delta Lake Enabled

# %%
# this sets up a spark connection in local mode, which we'll use for our simple single-node example
# for different cluster configurations (e.g., YARN mode), adjust this cell accordingly
# credentials would also be required here for ingesting files from cloud storage  
import pyspark
from delta import *
builder = pyspark.sql.SparkSession.builder.appName("DeltaTest") \
    .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension") \
    .config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog")
spark = configure_spark_with_delta_pip(builder).getOrCreate()

# %% [markdown]
# ### Ingest Raw Data into Spark DataFrame

# %%
# ingests CSV file we just downloaded into spark dataframe
# if we were using AWS S3--given appropriate credentials--just change to '.load("<S3 Bucket URL>")'
df = (spark.read.format("csv")
        .option("inferSchema", "true")
        .option("header", "true")
        .load("./Data/data.csv"))

# %% [markdown]
# ### Write Spark DataFrame Contents Into a Bronze Delta Table

# %%
df.write.format("delta").mode("overwrite").save("./delta/bronze/raw")

# %% [markdown]
# ### Load Delta Table Back Into Spark and Inspect Its Contents

# %%
data = spark.read.format("delta").load("./delta/bronze/raw")
data.select(data.columns[1:10]).show(10)
# Out:
# +--------------+--------------+--------------+--------------+--------------+--------------+--------------+-----------+-----------+
# |Product_Info_1|Product_Info_2|Product_Info_3|Product_Info_4|Product_Info_5|Product_Info_6|Product_Info_7|    Ins_Age|         Ht|
# +--------------+--------------+--------------+--------------+--------------+--------------+--------------+-----------+-----------+
# |             1|            A7|            26|           0.0|             2|             3|             1|0.611940299|0.763636364|
# |             1|            D4|            26|   0.487179487|             2|             1|             1|0.059701493|0.818181818|
# |             1|            D1|            26|   0.076923077|             2|             3|             1|0.656716418|0.709090909|
# |             1|            A8|            26|   0.076923077|             2|             3|             1|0.701492537|0.727272727|
# |             1|            D3|            10|   0.128205128|             2|             3|             1|0.417910448|0.654545455|
# |             1|            D1|            10|   0.487179487|             2|             1|             1|0.432835821|0.636363636|
# |             1|            D1|            26|   0.230769231|             2|             3|             1|0.552238806|0.636363636|
# |             1|            D3|            26|   0.076923077|             2|             3|             1|0.388059701|0.709090909|
# |             1|            A8|            26|   0.333333333|             2|             3|             1|0.731343284|0.654545455|
# |             1|            D4|            26|   0.743589744|             2|             1|             1|0.268656716|0.727272727|
# +--------------+--------------+--------------+--------------+--------------+--------------+--------------+-----------+-----------+
# only showing top 10 rows

# %% [markdown]
# ## Some Data Cleaning and Exploratory Analysis

# %% [markdown]
# ### Update Data Types

# %%
categorical = ["Product_Info_1","Product_Info_2","Product_Info_3","Product_Info_5","Product_Info_6","Product_Info_7","Employment_Info_2",
               "Employment_Info_3", "Employment_Info_5","InsuredInfo_1","InsuredInfo_2","InsuredInfo_3","InsuredInfo_4","InsuredInfo_5", 
               "InsuredInfo_6", "InsuredInfo_7","Insurance_History_1","Insurance_History_2","Insurance_History_3","Insurance_History_4", 
               "Insurance_History_7", "Insurance_History_8","Insurance_History_9","Family_Hist_1","Medical_History_2","Medical_History_3",
               "Medical_History_4","Medical_History_5", "Medical_History_6","Medical_History_7","Medical_History_8","Medical_History_9", 
               "Medical_History_11","Medical_History_12","Medical_History_13", "Medical_History_14","Medical_History_16",
               "Medical_History_17", "Medical_History_18","Medical_History_19","Medical_History_20","Medical_History_21", 
               "Medical_History_22","Medical_History_23", "Medical_History_25","Medical_History_26","Medical_History_27",
               "Medical_History_28","Medical_History_29", "Medical_History_30","Medical_History_31","Medical_History_33",
               "Medical_History_34","Medical_History_35","Medical_History_36","Medical_History_37", "Medical_History_38",
               "Medical_History_39","Medical_History_40", "Medical_History_41"]

# %%
continuous = ["Product_Info_4", "Ins_Age", "Ht", "Wt", "BMI", "Employment_Info_1", "Employment_Info_4", "Employment_Info_6", 
              "Insurance_History_5", "Family_Hist_2", "Family_Hist_3", "Family_Hist_4", "Family_Hist_5"]

# %%
discrete = ["Medical_History_1", "Medical_History_10", "Medical_History_15", "Medical_History_24", "Medical_History_32"]

# %%
dummy = ["Medical_Keyword_1",  "Medical_Keyword_2",  "Medical_Keyword_3",  "Medical_Keyword_4",  "Medical_Keyword_5",  
         "Medical_Keyword_6",  "Medical_Keyword_7",  "Medical_Keyword_8",  "Medical_Keyword_9", "Medical_Keyword_10", 
         "Medical_Keyword_11", "Medical_Keyword_12", "Medical_Keyword_13", "Medical_Keyword_14", "Medical_Keyword_15", 
         "Medical_Keyword_16", "Medical_Keyword_17", "Medical_Keyword_18", "Medical_Keyword_19", "Medical_Keyword_20", 
         "Medical_Keyword_21", "Medical_Keyword_22", "Medical_Keyword_23", "Medical_Keyword_24", "Medical_Keyword_25", 
         "Medical_Keyword_26", "Medical_Keyword_27", "Medical_Keyword_28", "Medical_Keyword_29", "Medical_Keyword_30", 
         "Medical_Keyword_31", "Medical_Keyword_32", "Medical_Keyword_33", "Medical_Keyword_34", "Medical_Keyword_35", 
         "Medical_Keyword_36", "Medical_Keyword_37", "Medical_Keyword_38", "Medical_Keyword_39", "Medical_Keyword_40", 
         "Medical_Keyword_41", "Medical_Keyword_42", "Medical_Keyword_43", "Medical_Keyword_44", "Medical_Keyword_45", 
         "Medical_Keyword_46", "Medical_Keyword_47", "Medical_Keyword_48"]

# %%
# update the schema of the spark dataframe with new data types
from pyspark.sql.types import *

for c in categorical:
    data = data.withColumn(c, data[c].cast(StringType()))

for c in continuous:
    data = data.withColumn(c, data[c].cast(FloatType()))
    
for c in discrete:
    data = data.withColumn(c, data[c].cast(ShortType()))

for c in dummy:
    data = data.withColumn(c, data[c].cast(BooleanType()))

# %% [markdown]
# ### Generate SILVER Delta Table for Cleaned Data

# %%
data.write.format("delta").mode("overwrite").save("./delta/SILVER_TABLE")

# %% [markdown]
# ### Inspect New Delta Table

# %%
data = spark.read.format("delta").load("./delta/SILVER_TABLE")
data.select(data.columns[1:10]).show(10)
data.select(data.columns[0:30]).printSchema()
# Out:
# +--------------+--------------+--------------+--------------+--------------+--------------+--------------+----------+----------+
# |Product_Info_1|Product_Info_2|Product_Info_3|Product_Info_4|Product_Info_5|Product_Info_6|Product_Info_7|   Ins_Age|        Ht|
# +--------------+--------------+--------------+--------------+--------------+--------------+--------------+----------+----------+
# |             1|            A7|            26|           0.0|             2|             3|             1| 0.6119403|0.76363635|
# |             1|            D4|            26|     0.4871795|             2|             1|             1|0.05970149| 0.8181818|
# |             1|            D1|            26|    0.07692308|             2|             3|             1| 0.6567164| 0.7090909|
# |             1|            A8|            26|    0.07692308|             2|             3|             1|0.70149255|0.72727275|
# |             1|            D3|            10|    0.12820512|             2|             3|             1|0.41791046| 0.6545454|
# |             1|            D1|            10|     0.4871795|             2|             1|             1|0.43283582| 0.6363636|
# |             1|            D1|            26|    0.23076923|             2|             3|             1| 0.5522388| 0.6363636|
# |             1|            D3|            26|    0.07692308|             2|             3|             1| 0.3880597| 0.7090909|
# |             1|            A8|            26|    0.33333334|             2|             3|             1|0.73134327| 0.6545454|
# |             1|            D4|            26|    0.74358976|             2|             1|             1|0.26865673|0.72727275|
# +--------------+--------------+--------------+--------------+--------------+--------------+--------------+----------+----------+
# only showing top 10 rows
#
# root
#  |-- Id: integer (nullable = true)
#  |-- Product_Info_1: string (nullable = true)
#  |-- Product_Info_2: string (nullable = true)
#  |-- Product_Info_3: string (nullable = true)
#  |-- Product_Info_4: float (nullable = true)
#  |-- Product_Info_5: string (nullable = true)
#  |-- Product_Info_6: string (nullable = true)
#  |-- Product_Info_7: string (nullable = true)
#  |-- Ins_Age: float (nullable = true)
#  |-- Ht: float (nullable = true)
#  |-- Wt: float (nullable = true)
#  |-- BMI: float (nullable = true)
#  |-- Employment_Info_1: float (nullable = true)
#  |-- Employment_Info_2: string (nullable = true)
#  |-- Employment_Info_3: string (nullable = true)
#  |-- Employment_Info_4: float (nullable = true)
#  |-- Employment_Info_5: string (nullable = true)
#  |-- Employment_Info_6: float (nullable = true)
#  |-- InsuredInfo_1: string (nullable = true)
#  |-- InsuredInfo_2: string (nullable = true)
#  |-- InsuredInfo_3: string (nullable = true)
#  |-- InsuredInfo_4: string (nullable = true)
#  |-- InsuredInfo_5: string (nullable = true)
#  |-- InsuredInfo_6: string (nullable = true)
#  |-- InsuredInfo_7: string (nullable = true)
#  |-- Insurance_History_1: string (nullable = true)
#  |-- Insurance_History_2: string (nullable = true)
#  |-- Insurance_History_3: string (nullable = true)
#  |-- Insurance_History_4: string (nullable = true)
#  |-- Insurance_History_5: float (nullable = true)

# %% [markdown]
# ## Delta Lake Table Versioning

# %%
# delta lake metadata keeps tracks of versions of the tables; 
# can be used for backtracking or auditing, if necessary
from delta.tables import *
deltaTable = DeltaTable.forPath(spark, "./delta/SILVER_TABLE")
deltaTable.history().select("version", "timestamp", "operation", "operationParameters").show()
# Out:
# +-------+--------------------+---------+--------------------+
# |version|           timestamp|operation| operationParameters|
# +-------+--------------------+---------+--------------------+
# |      0|2022-02-13 16:37:...|    WRITE|{mode -> Overwrit...|
# +-------+--------------------+---------+--------------------+

# %%
# after overwriting the delta table, we now have an additional version
# stored in metadata
data.write.format("delta").mode("overwrite").save("./delta/SILVER_TABLE")
deltaTable.history().select("version", "timestamp", "operation", "operationParameters").show()
# Out:
# +-------+--------------------+---------+--------------------+
# |version|           timestamp|operation| operationParameters|
# +-------+--------------------+---------+--------------------+
# |      1|2022-02-13 16:38:...|    WRITE|{mode -> Overwrit...|
# |      0|2022-02-13 16:37:...|    WRITE|{mode -> Overwrit...|
# +-------+--------------------+---------+--------------------+

# %%
# load up the first version ("@v0") of the silver delta table
data = spark.read.format("delta").load("./delta/SILVER_TABLE@v0")

# %% [markdown]
# ## Model Pipeline

# %% [markdown]
# ### Split Data

# %%
trainDF, testDF = data.randomSplit([.80, .20], seed = 100)

# %%
print("Train:", trainDF.count(), "\nTest: ", testDF.count())
# Out:
# Train: 47594
# Test:  11787

# %% [markdown]
# ### Convert Spark DataFrame Into Pandas-on-Spark DataFrame

# %%
import os
os.environ["PYARROW_IGNORE_TIMEZONE"] = "1"

# %%
# we can utilize all the familiar pandas functionality 
# while operating on spark dataframes 
pd_trainDF = trainDF.to_pandas_on_spark()
pd_trainDF.head(10)
# Out:
#       Id Product_Info_1 Product_Info_2 Product_Info_3  Product_Info_4 Product_Info_5 Product_Info_6 Product_Info_7   Ins_Age        Ht        Wt       BMI  Employment_Info_1 Employment_Info_2 Employment_Info_3  Employment_Info_4 Employment_Info_5  Employment_Info_6 InsuredInfo_1 InsuredInfo_2 InsuredInfo_3 InsuredInfo_4 InsuredInfo_5 InsuredInfo_6 InsuredInfo_7 Insurance_History_1 Insurance_History_2 Insurance_History_3 Insurance_History_4  Insurance_History_5 Insurance_History_7 Insurance_History_8 Insurance_History_9 Family_Hist_1  Family_Hist_2  Family_Hist_3  Family_Hist_4  Family_Hist_5  Medical_History_1 Medical_History_2 Medical_History_3 Medical_History_4 Medical_History_5 Medical_History_6 Medical_History_7 Medical_History_8 Medical_History_9  Medical_History_10 Medical_History_11 Medical_History_12 Medical_History_13 Medical_History_14  Medical_History_15 Medical_History_16 Medical_History_17 Medical_History_18 Medical_History_19 Medical_History_20 Medical_History_21 Medical_History_22 Medical_History_23  Medical_History_24 Medical_History_25 Medical_History_26 Medical_History_27 Medical_History_28 Medical_History_29 Medical_History_30 Medical_History_31  Medical_History_32 Medical_History_33 Medical_History_34 Medical_History_35 Medical_History_36 Medical_History_37 Medical_History_38 Medical_History_39 Medical_History_40 Medical_History_41  Medical_Keyword_1  Medical_Keyword_2  Medical_Keyword_
               False               False               False               False               False               False               False               False               False               False               False               False               False               False               False               False               False               False               False               False               False               False               False               False               False               False               False               False               False               False               False               False               False               False               False               False               False               False               False         6
# 9  23962              1             D4             26        1.000000              2              3              1  0.194030  0.781818  0.278243  0.379321              0.080                 9                 1             0.0000                 2           0.004000             1             2             1             3             1             1             1                   1                   1                   3                   1         1.510000e-07                   1                   1                   2             3       0.246377            NaN       0.197183            NaN                NaN               162                 2                 2                 1                 3                 2                 2                 2                 NaN                  3                  2                  3                  3                 NaN                  1                  3                  1                  1                  2                  1                  2                  3                 NaN                  1                  3                  3                  1                  3                  2                  3                 NaN                  3                  3                  1                  2                  2                  1                  3                  3                  1              False              False              False              False              False              False              False              False              False               False               False               False               False               False               False               False               False               False               False               False               False               False               False               False               False               False               False               False               False               False               False               False               False               False               False               False               False               False               False               False               False               False               False               False               False               False               False               False         8

# %% [markdown]
# ### Identify Columns to be Omitted

# %%
# identify columns with >40% missing values
many_missing = pd_trainDF.isna().sum()/len(pd_trainDF) > 0.4
missing = list(pd_trainDF.loc[:,many_missing.values].columns)
missing
# Out:
# ['Insurance_History_5',
#  'Family_Hist_2',
#  'Family_Hist_3',
#  'Family_Hist_5',
#  'Medical_History_10',
#  'Medical_History_15',
#  'Medical_History_24',
#  'Medical_History_32']

# %%
# identify categorical vars with many levels
pd_trainDF[categorical].nunique()
# Out:
# Product_Info_1           2
# Product_Info_2          19
# Product_Info_3          31
# Product_Info_5           2
# Product_Info_6           2
# Product_Info_7           3
# Employment_Info_2       35
# Employment_Info_3        2
# Employment_Info_5        2
# InsuredInfo_1            3
# InsuredInfo_2            2
# InsuredInfo_3           11
# InsuredInfo_4            2
# InsuredInfo_5            2
# InsuredInfo_6            2
# InsuredInfo_7            2
# Insurance_History_1      2
# Insurance_History_2      3
# Insurance_History_3      3
# Insurance_History_4      3
# Insurance_History_7      3
# Insurance_History_8      3
# Insurance_History_9      3
# Family_Hist_1            3
# Medical_History_2      544
# Medical_History_3        3
# Medical_History_4        2
# Medical_History_5        3
# Medical_History_6        3
# Medical_History_7        3
# Medical_History_8        3
# Medical_History_9        3
# Medical_History_11       3
# Medical_History_12       3
# Medical_History_13       3
# Medical_History_14       3
# Medical_History_16       3
# Medical_History_17       2
# Medical_History_18       3
# Medical_History_19       3
# Medical_History_20       3
# Medical_History_21       3
# Medical_History_22       2
# Medical_History_23       3
# Medical_History_25       3
# Medical_History_26       3
# Medical_History_27       3
# Medical_History_28       3
# Medical_History_29       3
# Medical_History_30       3
# Medical_History_31       3
# Medical_History_33       2
# Medical_History_34       3
# Medical_History_35       3
# Medical_History_36       3
# Medical_History_37       3
# Medical_History_38       2
# Medical_History_39       3
# Medical_History_40       3
# Medical_History_41       3
# dtype: int64

# %%
# identify predictors
disregard = missing + ['Id', 'Medical_History_2', 'Response']
predictors = [x for x in pd_trainDF.columns if x not in disregard]

# %% [markdown]
# ### Generate a Hashed Feature Vector of Remaining Columns

# %%
# this does one-hot encoding on categorical variables and generates
# a sparse feature vector, which improves computation efficiency 
from pyspark.ml.feature import FeatureHasher
hasher = FeatureHasher(inputCols = predictors,
                       outputCol = "hashed_features")

# %% [markdown]
# ### Discard Zero-Variance Features

# %%
from pyspark.ml.feature import VarianceThresholdSelector
selector = VarianceThresholdSelector(featuresCol = hasher.getOutputCol(), outputCol = "features")

# %% [markdown]
# ### Random Forest Model Spec

# %%
from pyspark.ml.classification import RandomForestClassifier
rf = RandomForestClassifier(labelCol = 'Response', seed = 200)

# %% [markdown]
# ### Hyperparameter Tuning Grid

# %%
from pyspark.ml.tuning import ParamGridBuilder
paramGrid = (ParamGridBuilder()
            .addGrid(rf.maxDepth, [2, 4, 6])
            .addGrid(rf.numTrees, [50, 150])
            .build())

# %% [markdown]
# ### Evaluation Metric

# %%
from pyspark.ml.evaluation import MulticlassClassificationEvaluator
evaluator = MulticlassClassificationEvaluator(labelCol = "Response",
                                              predictionCol = "prediction",
                                              metricName = "accuracy")

# %% [markdown]
# ### Cross-Validation Process

# %%
from pyspark.ml.tuning import CrossValidator
cv = CrossValidator(estimator = rf,
                    evaluator = evaluator,
                    estimatorParamMaps = paramGrid,
                    numFolds = 10,
                    parallelism = 4,
                    seed = 300)

# %% [markdown]
# ### Construct the Model Pipeline

# %%
from pyspark.ml import Pipeline
pipeline = Pipeline(stages = [hasher, selector, cv])

# %% [markdown]
# ### Fit the Model on Training Data Using the Pipeline

# %%
# performs 10-fold cross-validation to identify best set of hyperparameters, 
# then fits the model on the entire training set
pipelineModel = pipeline.fit(trainDF)

# %% [markdown]
# ## Model Evaluation

# %% [markdown]
# ### Predictions on Testing Set

# %%
predDF = pipelineModel.transform(testDF)
predDF.select("features", "Response", "prediction").show(10)
# Out:
# +--------------------+--------+----------+
# |            features|Response|prediction|
# +--------------------+--------+----------+
# |(359,[1,7,10,13,1...|       6|       8.0|
# |(359,[1,7,10,13,1...|       7|       8.0|
# |(359,[1,7,10,13,1...|       8|       8.0|
# |(359,[1,6,7,10,13...|       8|       8.0|
# |(359,[6,7,10,13,1...|       8|       8.0|
# |(359,[1,6,7,10,13...|       4|       8.0|
# |(359,[1,7,10,13,1...|       8|       8.0|
# |(359,[1,6,7,10,13...|       6|       6.0|
# |(359,[1,7,13,15,2...|       1|       6.0|
# |(359,[1,7,10,13,1...|       8|       8.0|
# +--------------------+--------+----------+
# only showing top 10 rows

# %% [markdown]
# ### Evaluate Accuracy on Testing Set

# %%
evaluator.evaluate(predDF)
# Out:
# 0.43734622889624164

# %% [markdown]
# ### Confusion Matrix

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
predictions = predDF.select("Response", "prediction").to_pandas_on_spark()
r = predictions['Response'].to_numpy()
p = predictions['prediction'].to_numpy()
cm = confusion_matrix(r,p)
ax = sns.heatmap(cm, annot = True, fmt = 'g', 
                 cmap = sns.color_palette("ch:s = -.2, r = .6", as_cmap = True))
ax.set_xlabel('Predicted Response')
ax.set_ylabel('Actual Response');
ax.xaxis.set_ticklabels(range(1,9))
ax.yaxis.set_ticklabels(range(1,9))
plt.show()
